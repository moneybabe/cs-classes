# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
# Load data
df = pd.read_csv('measurements.csv')
df['nanoseconds'] = signal.medfilt(df['nanoseconds'], kernel_size=31)

# %%
plt.plot(df['n'], df['nanoseconds'])
plt.title('mysteryA')
# Out:
# Text(0.5, 1.0, 'mysteryA')
